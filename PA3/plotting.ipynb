# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# ## Load required files

# %%
#load the validation, training loss and iou accuracy calculated on validation set
loss = np.load('./losses.npy')
loss_val = np.load('./losses_val.npy')
pixel_acc = np.load('./p_acc.npy', allow_pickle=True)
iou_acc = np.load('./iou_acc.npy')

# %% [markdown]
# ## Plot Loss vs Epochs

# %%
plt.figure()
plt.plot(loss, label='Training Loss')
plt.plot(loss_val, label='Validation Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss vs Epochs')
plt.savefig('Additional_architecture_loss_epochs')
