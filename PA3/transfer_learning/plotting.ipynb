# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
# Load files
loss_train = np.load('./encoder_vgg11_results(gradients_exploded)/losses.npy')
loss_val = np.load('./encoder_vgg11_results(gradients_exploded)/losses_val.npy')

# %%
fig, axs = plt.subplots(1,1, figsize=(15,5))
# axs = axs.flatten()
axs.plot(loss_train, c='b')
axs.plot(loss_val, c='r')
axs.set_xlabel('Iteration')
axs.set_title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
fig, ax = plt.subplots(figsize=(9,5))
ax.plot(iou_acc)
ax.set_xlabel('Iteration')
ax.set_title('IOU Accuracy')
# Out:
# Text(0.5, 1.0, 'IOU Accuracy')
